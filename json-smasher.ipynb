# %% [markdown]
# ## Libraries

# %%
import pandas as pd
import numpy as np
import json
import os
import csv
from tqdm import tqdm

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Flattener function

# %%
def flatten_nested_df(df):
    list_error = []
    dict_error = []

    try:
        s = (df.applymap(type) == list).any()
        list_columns = s[s].index.tolist()

        s = (df.applymap(type) == dict).any()
        dict_columns = s[s].index.tolist()

        while (len(list_columns) > 0 or len(dict_columns) > 0) and ((set(list_columns) != set(list_error)) or (set(dict_columns) != set(dict_error))):
            for x in list_columns:
                try:
                    df = df.explode(x, ignore_index=False)
                    df = df.reset_index(drop=True)
                except:
                    print(f"Error en: {x}")
                    list_error.append(x)
                    pass

            for y in dict_columns:
                try:
                    df_new = pd.json_normalize(df[y].dropna()).add_prefix(f'{y}.')
                    df = df.merge(df_new, how='left', left_index=True, right_index=True)
                    del(df[y])
                except:
                    print(f"Error en: {y}")
                    dict_error.append(y)
                    pass

            s = (df.applymap(type) == list).any()
            list_columns = s[s].index.tolist()

            s = (df.applymap(type) == dict).any()
            dict_columns = s[s].index.tolist()
        
        return df
    except:
        return df

# %% [markdown]
# ### Verify flattening

# %%
def verify_flattening(df):
    s = (df.applymap(type) == list).any()
    list_columns = s[s].index.tolist()
    
    s = (df.applymap(type) == dict).any()
    dict_columns = s[s].index.tolist()

    print(f"Listas: {list_columns}, Diccionarios: {dict_columns}")

# %% [markdown]
# ### Remove unwanted columns

# %%
def remove_columns_df(df, list_columns):
    columns_to_drop = [col for col in df.columns if col not in list_columns]
    df.drop(columns = columns_to_drop, inplace = True)
    df.drop_duplicates(inplace = True)
    
    return df

# %% [markdown]
# ### Iteration pipeline

# %%
def smasher_filtered(json_data, list_columns):
    stage_df = pd.DataFrame()
    total_documents = len(json_data)

    with tqdm(total = total_documents) as pbar:
        for x in range(0, total_documents):
            j_norm = pd.json_normalize(json_data[x])
            j_flat = flatten_nested_df(j_norm)
            stage_df = pd.concat([remove_columns_df(j_flat), stage_df])
            pbar.update(1)
            
    print(f"Completed. Final dataframe shape: {stage_df.shape}")
    return stage_df

# %%
def smasher(json_data):
    stage_df = pd.DataFrame()
    total_documents = len(json_data)

    with tqdm(total = total_documents) as pbar:
        for x in range(0, total_documents):
            j_norm = pd.json_normalize(json_data[x])
            j_flat = flatten_nested_df(j_norm)
            stage_df = pd.concat([j_flat, stage_df])
            pbar.update(1)
        
    print(f"Completed. Final dataframe shape: {stage_df.shape}")
    return stage_df

# %% [markdown]
# ## Parameters

# %%
PARAM = {}

# Working directory
PARAM['working_directory'] = "C:/Users/ferna/OneDrive - Universidad Austral/Git/json-smasher"

# Input file name
PARAM['input_file_name'] = "large-file.json"

# Output file name
PARAM['output_file_name'] = "large-file"
PARAM['output_excel'] = True

# Filters
PARAM['col_filter'] = False
columns_filter = []

PARAM['row_filter'] = False
rows_filter = range(0,10)

# %% [markdown]
# ## Read json file

# %%
with open('large-file.json', 'r', encoding="utf8") as f:
    json_data = json.load(f)

# %% [markdown]
# ## Filter (Optional)

# %%
if PARAM['col_filter'] and PARAM['row_filter']:
    filtered_rows = json_data[rows_filter]
    filtered_json = [{k:v for k,v in d.items() if k in columns_filter} for d in json_data]
elif PARAM['col_filter']:
    filtered_json = [{k:v for k,v in d.items() if k in columns_filter} for d in json_data]
elif PARAM['row_filter']:
    filtered_json = json_data[rows_filter]
else:
    filtered_json = json_data

# %% [markdown]
# ## Execute

# %%
middle_flat = smasher(json_data)
# Out:
#   0%|          | 0/11351 [00:00<?, ?it/s]
# 100%|██████████| 11351/11351 [42:34<00:00,  4.44it/s]
# Completed. Final dataframe shape: (15931, 657)

# %% [markdown]
# ## Remove duplicated records

# %%
initial_length = len(middle_flat)
final_flat = middle_flat.drop_duplicates()
final_length = len(final_flat)

if (initial_length == final_length):
    print('No duplicates found')
else:
    print( f'Initial length was: {initial_length}, and after removing duplicates is: {final_length}')
# Out:
# No duplicates found

# %% [markdown]
# ## Save to file

# %%
if PARAM['output_excel']:
    xlsx_path = PARAM['working_directory']+'/'+PARAM['output_file_name']+'.xlsx'
    #final_flat.to_excel(xlsx_path, index=False)
    writer = pd.ExcelWriter(xlsx_path, engine="xlsxwriter", options={'strings_to_urls': False})
    final_flat.to_excel(writer)
    writer.save()
else:
    csv_path = os.path.join(PARAM['working_directory'], PARAM['output_file_name']+'.csv')
    final_flat.to_csv(csv_path, sep=',', index=False, encoding="utf-8", quoting=csv.QUOTE_NONNUMERIC)
# Out:
# C:\Users\ferna\AppData\Local\Temp\ipykernel_11924\2293286817.py:4: FutureWarning: Use of **kwargs is deprecated, use engine_kwargs instead.
#   writer = pd.ExcelWriter(xlsx_path, engine="xlsxwriter", options={'strings_to_urls': False})
# c:\Users\ferna\anaconda3\lib\site-packages\xlsxwriter\workbook.py:339: UserWarning: Calling close() on already closed file.
#   warn("Calling close() on already closed file.")

# %%
final_flat
# Out:
#             id         type  public            created_at  actor.id  \
# 0   2489678844  IssuesEvent    True  2015-01-01T15:59:59Z   9343331
# 0   2489678843  IssuesEvent    True  2015-01-01T15:59:59Z   9343331
# 0   2489678842  DeleteEvent    True  2015-01-01T15:59:59Z   2057932
# 0   2489678840  IssuesEvent    True  2015-01-01T15:59:59Z   9343331
# 0   2489678838  IssuesEvent    True  2015-01-01T15:59:59Z   1105372
# ..         ...          ...     ...                   ...       ...
# 0   2489651062    PushEvent    True  2015-01-01T15:00:03Z    485033
# 0   2489651057   WatchEvent    True  2015-01-01T15:00:03Z   6894991
# 0   2489651053    PushEvent    True  2015-01-01T15:00:01Z   6339799
# 0   2489651051    PushEvent    True  2015-01-01T15:00:01Z   3854017
# 0   2489651045  CreateEvent    True  2015-01-01T15:00:00Z    665991
#
#         actor.login actor.gravatar_id  \
# 0           No-CQRT
# 0           No-CQRT
# 0           LipkeGu
# 0           No-CQRT
# 0            ophian
# ..              ...               ...
# 0          winterbe
# 0   SametSisartenep
# 0           izuzero
# 0              rspt
# 0           petroav
#
#                                        actor.url  \
# 0           https://api.github.com/users/No-CQRT
# 0           https://api.github.com/users/No-CQRT
# 0           https://api.github.com/users/LipkeGu
# 0           https://api.github.com/users/No-CQRT
# 0            https://api.github.com/users/ophian
# ..                                           ...
# 0          https://api.github.com/users/winterbe
# 0   https://api.github.com/users/SametSisartenep
# 0           https://api.github.com/users/izuzero
# 0              https://api.github.com/users/rspt
# 0           https://api.github.com/users/petroav
#
#                                     actor.avatar_url   repo.id  ...  \
# 0   https://avatars.githubusercontent.com/u/9343331?  25600089  ...
# 0   https://avatars.githubusercontent.com/u/9343331?  25600089  ...
# 0   https://avatars.githubusercontent.com/u/2057932?  24847217  ...
# 0   https://avatars.githubusercontent.com/u/9343331?  25600089  ...
# 0   https://avatars.githubusercontent.com/u/1105372?   2627116  ...
# ..                                               ...       ...  ...
# 0    https://avatars.githubusercontent.com/u/485033?  28593843  ...
# 0   https://avatars.githubusercontent.com/u/6894991?   2871998  ...
# 0   https://avatars.githubusercontent.com/u/6339799?  28270952  ...
# 0   https://avatars.githubusercontent.com/u/3854017?  28671719  ...
# 0    https://avatars.githubusercontent.com/u/665991?  28688495  ...
#
#    payload.release.assets.uploader.gists_url  \
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# ..                                       ...
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
#
#    payload.release.assets.uploader.starred_url  \
# 0                                          NaN
# 0                                          NaN
# 0                                          NaN
# 0                                          NaN
# 0                                          NaN
# ..                                         ...
# 0                                          NaN
# 0                                          NaN
# 0                                          NaN
# 0                                          NaN
# 0                                          NaN
#
#    payload.release.assets.uploader.subscriptions_url  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# ..                                               ...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#    payload.release.assets.uploader.organizations_url  \
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# ..                                               ...
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
# 0                                                NaN
#
#    payload.release.assets.uploader.repos_url  \
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# ..                                       ...
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
# 0                                        NaN
#
#    payload.release.assets.uploader.events_url  \
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# ..                                        ...
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
# 0                                         NaN
#
#    payload.release.assets.uploader.received_events_url  \
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# ..                                                ...
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
#
#    payload.release.assets.uploader.type  \
# 0                                   NaN
# 0                                   NaN
# 0                                   NaN
# 0                                   NaN
# 0                                   NaN
# ..                                  ...
# 0                                   NaN
# 0                                   NaN
# 0                                   NaN
# 0                                   NaN
# 0                                   NaN
#
#     payload.release.assets.uploader.site_admin  payload.pull_request.head.repo
# 0                                          NaN                             NaN
# 0                                          NaN                             NaN
# 0                                          NaN                             NaN
# 0                                          NaN                             NaN
# 0                                          NaN                             NaN
# ..                                         ...                             ...
# 0                                          NaN                             NaN
# 0                                          NaN                             NaN
# 0                                          NaN                             NaN
# 0                                          NaN                             NaN
# 0                                          NaN                             NaN
#
# [15931 rows x 657 columns]
